# %% [markdown]
# # AULA 03 VARIÁVEIS

# %% [markdown]
# ## OLÁ MUNDO

# %%
print("OLÁ MUNDO")
# Out:
# OLÁ MUNDO

# %% [markdown]
# # TIPOS DE VARIÁVEIS

# %%
numero=32
numero_frac=15,2
texto="Papagaio"

# %%
type(numero)
# Out:
# int

# %%
type(texto)
# Out:
# str

# %%
type(numero_frac)
# Out:
# tuple

# %%
print(type(numero))
print(type(numero_frac))
print(type(texto))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %%
texto.upper()
# Out:
# 'PAPAGAIO'

# %%
numero_frac=15.2

# %%
type(numero_frac)
# Out:
# float

# %%
numero_inteiro=15

# %%
numero_real=15,15

# %%
texto="Daiana"

# %%
type(numero_inteiro)
# Out:
# int

# %%
type(texto)
# Out:
# str

# %%
type(numero_real)
# Out:
# tuple

# %%
numero_real=15.15

# %%
type(numero_real)
# Out:
# float

# %%
numero+numero_real
# Out:
# 47.15

# %%
numero+texto
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 numero+texto
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
texto*numero
# Out:
# 'cincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocincocinco'

# %%
texto2=texto+" "+texto

# %%
texto2*numero
# Out:
# 'Daiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana DaianaDaiana Daiana'

# %%
idade=input("Digite a sua idade")

# %%
type(idade)
# Out:
# str

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
idade_numero=int(idade)

# %%
type(idade_numero)
# Out:
# int

# %%
idade_numero_2=int(input("Qual a sua idade"))

# %%
type(idade_numero_2)
# Out:
# int

# %%
ANO_ATUAL=2025

# %%
idade_numero_2=int(input("Qual a sua idade"))

# %%
ano_nascimento=ANO_ATUAL - idade_numero_2

# %%
print(ano_nascimento)
# Out:
# 1995
