# %% [markdown]
# # Aula 8 - Funções

# %% [markdown]
# ## 8.1 Funções simples

# %%
def soma (a,b):
    soma= a + b
    return soma

# %%
resultado=soma(12.4,15)
print(f"O resultado é .:{resultado:4.2f}:.")
# Out:
# O resultado é .:27.40:.

# %%
def soma_2 (n1,n2):
    soma=n1+n2
    print(soma)

# %%
soma_2(12.4,15)
# Out:
# 27.4
