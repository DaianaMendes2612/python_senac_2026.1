# %% [markdown]
# # AULA 04

# %% [markdown]
# ## ATIVIDADE 7

# %%
meu_livro = "Python para Iniciantes"
print(meu_livro)
# Out:
# Python para Iniciantes

# %%
meu_livro = "Algoritmos Divertidos"
print(meu_livro)
# Out:
# Algoritmos Divertidos

# %%
PI = 3.14159
GRAVIDADE = 9.8

# %%
meu_livro = 30
print(meu_livro)
# Out:
# 30

# %%
PI = 3.14159
GRAVIDADE = 9.8

# %%
nome=input("Digite o seu nome: ")

# %%
ano_nascimento=input("Digite o ano de nascimento: ")

# %%
print(f"Seu nome é: {nome}")
# Out:
# Seu nome é: Daiana

# %%
nascimento = int(ano_nascimento)

# %%
Ano_Atual=2026

# %%
inteiro=19
ponto_flutuante=3.14
numero_complexo=2 + 3j

# %%
print(type(inteiro))
# Out:
# <class 'int'>

# %%
print(type(ponto_flutuante))
# Out:
# <class 'float'>

# %%
print(type(numero_complexo))
# Out:
# <class 'complex'>

# %%
type(Ano_Atual)
# Out:
# int

# %%
type(ano_nascimento)
# Out:
# int

# %%
id=(Ano_Atual-ano_nascimento)

# %%
print(id)
# Out:
# 40

# %% [markdown]
# # TESTANDO AS STRINGS

# %%
nome= "Daiana Mendes"

# %%
Endereço= "Rua Atilio Maroti, 1511 - Quarteirão Brasileiro"

# %%
saudacao="""Olá, meu nome é Daiana. 
estou aprendendo a programar em Pyton. 
Faço aulas as segunda, quartas e sextas-feiras das 18h as 22h"""

# %%
print(nome)
# Out:
# Daiana Mendes

# %%
print(Endereço)
# Out:
# Rua Atilio Maroti, 1511 - Quarteirão Brasileiro

# %%
print(saudacao)
# Out:
# Olá, meu nome é Daiana.
# estou aprendendo a programar em Pyton.
# Faço aulas as segunda, quartas e sextas-feiras das 18h as 22h

# %% [markdown]
# # VARIÁVEIS BOOLEANOS(BOLL)

# %%
# Utilizada para fazer testes, 
# avaliações condicionais - 
# retornam verdadeira ou falsa

# %%
verdadeiro = True
falso = False

# %%
print(type(verdadeiro))
# Out:
# <class 'bool'>

# %%
numero1=5
numero2=7

# %%
numero1>numero2
# Out:
# False

# %%
numero1<numero2
# Out:
# True

# %%
usuario = ("Ana", 28, "Rio de Janeiro")

# %%
print(usuario[2])
# Out:
# Rio de Janeiro

# %%
produto = ("Notebook", 3500.99, True)

# %%
print(produto[0])
# Out:
# Notebook

# %%
minha_lista = ["banana", "maçã", 10, True]

# %%
print(minha_lista[0])
# Out:
# banana

# %%
compras = ["arroz", "feijão"]

# %%
compras.append("azeite")

# %%
print(compras[2])
# Out:
# azeite

# %%
compras.append("jiló")

# %%
print(compras[3])
# Out:
# jiló

# %%
6==6
# Out:
# True

# %%
10!=10
# Out:
# False

# %%
10>=10
# Out:
# True

# %%
6<=2
# Out:
# False

# %%
nome = input("Digite o seu nome: ")
ano_nascimento = int(input("Digite o ano do seu nascimento: "))

# %%
ano_atual=2026

# %%
idade=ano_atual-ano_nascimento

# %%
if idade >=18:
        print("Você é maior de idade")
elif idade>=17:
        print("Você é adolescente")
else:
        print("Você é criança")
# Out:
# Você é maior de idade

# %%
print(f"Você tem ou vai fazer {idade} anos em {ano_atual}.")
# Out:
# Você tem ou vai fazer 47 anos em 2026.
